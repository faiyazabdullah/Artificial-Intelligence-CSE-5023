# %%
import numpy as np

# %%
data = np.genfromtxt('/content/data.csv',delimiter=',')

# %%
n = data.shape[0]

# %%
k=6

# %%
center_idx = np.random.choice(n,k,replace=False)

# %%
centers = list()

# %%
for i in center_idx:
  centers.append(data[i].tolist())

# %%
centers
# Out:
# [[1.42944406596034, 8.275098323858487],
#  [8.3871642472255, 0.024961665615355955],
#  [0.4599922028895612, 8.833005321835966],
#  [1.5953361410681932, 7.156772783518236],
#  [4.292698229804196, 4.664665553196606],
#  [7.0900191250959494, 3.6277143895557895]]

# %%
centers = data[np.random.choice(n,k,replace=False)]

# %%
def calc_distance(a,b):
  dist = 0;
  for x1,x2 in zip(a,b):
    dist += (x1-x2)**2
  return dist**0.5

# %%
#it's a bad decision
for s in data:
  idx = -1
  min = 999
  for i,c in enumerate(centers):
    dst = calc_distance(s,c)
    if min>dst:
      min = dst
      idx = i

# %%
data[0]
# Out:
# array([0.20987452, 2.00290685])

# %%
centers[0]
# Out:
# array([0.70647349, 6.11825379])

# %%
((data[0]-centers[0])**2).sum()**0.5
# Out:
# 4.145200958990989

# %%
((data[0]-centers[1])**2).sum()**0.5
# Out:
# 14.021061818766377

# %%
distance = np.zeros((n,k))
for i in range(k):
  distance[:,i] = ((data-centers[i])**2).sum(axis=1)**0.5

# %%
closest = np.argmin(distance,axis=1)

# %%
for i in range(k):
  centers[i] = data[closest==i].mean(axis=0)

# %%
centers
# Out:
# array([[ 0.90983553,  3.75259373],
#        [12.9786205 ,  5.04774052],
#        [12.95924491, 13.08169599],
#        [ 0.77081987,  8.43000602],
#        [ 7.93102952,  0.76108497],
#        [ 3.99846724,  3.52821606]])

# %%
old_closest = closest.copy()

# %%
if all(old_closest==closest)
  break

# %%
#you have to write a function kmeans()
def kmeans(X,k):
  pass

# %%
from matplotlib import pyplot as plt

# %%
plt.scatter(data[:,0],data[:,1],c=closest)
plt.scatter(centers[:,0],centers[:,1],marker='*')
plt.show()
